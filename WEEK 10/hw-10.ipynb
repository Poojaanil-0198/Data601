# %% [markdown]
# # Week 10 Homework
#
# Extend the following class and name this class `ModuleLister`
#
#
# This will find all unique modules in your homework and labs.

# %%
### DON'T CHANGE THIS CELL
import os

class FileProcessor:
    
    def __init__(self, path, file_types=['.ipynb']):
        self.files = self.find_all_files(path, file_types)
        print(f'{len(self.files)} file(s) found...')

    
    def find_all_files(self, path, file_types):
        paths = []
        for root, dirs, files in os.walk(path):
            for file in files:
                if any([file.endswith(ft) for ft in file_types]):
                    path = os.path.join(root, file)
                    # print(path)
                    paths.append(path)
        return paths
    
    def read_file(self, file_path, encoding='utf8'):
        with open(file_path,encoding=encoding) as f:
            return f.read()
    
    def start(self):
        """
        Entry point for the class
        """
        for file in self.files:
            self.process_file(file)
        
    def process_file(self, file_path):
        """
        abstract method
        """
        raise NotImplemented('process_file method not implemented')

# %%
### your code starts here
import pkg_resources
import sys
import json
import re
class ModuleLister(FileProcessor):
    def __init__(self):
        super().__init__(path='/Users/poojaanil/', file_types=['.ipynb'])
    
    def process_file(self, file_path):
        try:
            content = self.read_file(file_path)
            data = re.findall(r"import (\w+)", content)
            if (data != []):
                print(file_path, ':', data)
                
                
            
            #if 'pneumonia' in content:
                #print(content)
                
                
#             data = re.compile(r'import (\s+)')
#             data1 = re.findall(data, content)
#             print(data1)
           
                                    
            
            
            
#             for i in content:
#                 match = re.search(r'import (\w+)', i)
#                 if match:
#                     print(match)
#             installed_packages  = pkg_resources.working_set
#             installed_packages_list = sorted(["%s==%s" % (i.key, i.version) for i in installed_packages])
#             for j in installed_packages_list:
#                 print(j)
            
          
        
        except Exception as e:
            print('--- ERRROR', file_path, str(e))

# %%
# !pwd
# Out:
# /Users/poojaanil

# %%
#processor = ModuleLister(path='../') # change the path according to your path

# %%
ModuleLister().start()
# Out:
# 231 file(s) found...
# /Users/poojaanil/Get Browser History.ipynb : ['Firefox', 'browserhistory', 'pandas', 'urlparse']
# /Users/poojaanil/MIDTERM_DATA601-Copy1.ipynb : ['pandas', 'pandas', 'numpy', 'random', 'seaborn', 'pyplot']
# /Users/poojaanil/midterm.ipynb : ['pandas', 'numpy', 'seaborn', 'pyplot', 'missingno']
# /Users/poojaanil/hw-10.ipynb : ['os', 'pkg_resources', 'sys', 'json', 're']
# /Users/poojaanil/Copy_of_week08_lab.ipynb : ['pandas', 'pandas', 'ai', 'data', 'data', 'ai', 'data', 're']
# /Users/poojaanil/Data Visualization basics - DATA 601.ipynb : ['random', 'pandas', 'matplotlib', 'numpy', 'to']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 07/hw-07.ipynb : ['Faker', 'pandas', 'numpy', 'randint', 'random', 'seaborn', 'pyplot']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 08/week08_lab.ipynb : ['pandas', 'pandas', 'data', 're']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 08/hw-08.ipynb : ['pandas', 'pandas', 're']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 06/hw-06.ipynb : ['ZipFile', 'request', 'pyplot', 'numpy']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 06/week06_lab.ipynb : ['ZipFile', 'request', 'pandas', 'seaborn']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 10/week10_lab.ipynb : ['numpy']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 10/hw10-browser_history.ipynb : ['pandas', 'matplotlib', 'matplotlib']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 03/HW-03.ipynb : ['random', 'operator', 'random', 'datetime', 'date', 're']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 03/lab3.ipynb : ['pandas']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 04/hw-04.ipynb : ['pandas', 'DataFrame', 'csv', 'math', 'seaborn', 'numpy', 'matplotlib']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 04/lab04.ipynb : ['pandas']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 05/hw-05.ipynb : ['pandas', 'seaborn', 'pyplot', 'numpy']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 05/week5_lab.ipynb : ['seaborn', 'pandas']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 02/lab2.ipynb : ['pandas', 'matplotlib']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 02/Homework2.ipynb : ['random', 'matplotlib', 'numpy', 'mean']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/MIDTERM/MIDTERM_DATA601.ipynb : ['pandas', 'pandas', 'numpy', 'random', 'seaborn', 'pyplot']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/Data601/WEEK 09 /hw_09.ipynb : ['pandas', 'matplotlib', 'matplotlib']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week01/1_basics.ipynb : ['fuzzywuzzy', 'fuzz']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/2_modeling_random_coin_flips.ipynb : ['random', 'timeit']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/1_1_some_basics.ipynb : ['this', 'random']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/3_modeling_random_coin_flips_visualization.ipynb : ['random', 'pandas', 'matplotlib', 'numpy']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/4_binomial distribution for coin flips.ipynb : ['random', 'matplotlib', 'seaborn', 'pandas', 'numpy']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/5_visualizing_time_variation_v5_final_product_looks_easy.ipynb : ['pandas', 'matplotlib', 'matplotlib']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/1_2_tuples_arrays_functions_summary.ipynb : ['datetime']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/Week02 - visualization.ipynb : ['matplotlib', 'matplotlib', 'matplotlib', 'numpy', 'colors', 'PercentFormatter', 'pandas']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/lab/lab2.ipynb : ['pandas', 'matplotlib']
# /Users/poojaanil/Desktop/Data601_HomeworkFolder/DS601_Spring22/Week02/homework/HW-02.ipynb : ['random', 'matplotlib']
# /Users/poojaanil/Desktop/DS601_Spring22/Week01/1_basics.ipynb : ['fuzzywuzzy', 'fuzz']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/2_modeling_random_coin_flips.ipynb : ['random', 'timeit']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/1_1_some_basics.ipynb : ['this', 'random']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/3_modeling_random_coin_flips_visualization.ipynb : ['random', 'pandas', 'matplotlib', 'numpy']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/4_binomial distribution for coin flips.ipynb : ['random', 'matplotlib', 'seaborn', 'pandas', 'numpy']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/5_visualizing_time_variation_v5_final_product_looks_easy.ipynb : ['pandas', 'matplotlib', 'matplotlib']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/1_2_tuples_arrays_functions_summary.ipynb : ['datetime']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/Week02 - visualization.ipynb : ['matplotlib', 'matplotlib', 'matplotlib', 'numpy', 'colors', 'PercentFormatter', 'pandas']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/lab/lab2.ipynb : ['pandas', 'matplotlib']
# /Users/poojaanil/Desktop/DS601_Spring22/Week02/homework/HW-02.ipynb : ['random', 'matplotlib']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/week03_2.ipynb : ['pandas', 'pandas', 'matplotlib']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/load_csv.ipynb : ['csv', 'pandas']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/week03_1.ipynb : ['pandas']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/load_xml.ipynb : ['xmltodict', 'json', 'OrderedDict', 'minidom', 'xml', 'pandas']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/load_json.ipynb : ['json']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/lab/lab3.ipynb : ['pandas']
# /Users/poojaanil/Desktop/DS601_Spring22/Week03/homework/HW-03.ipynb : ['random', 'datetime', 're']
# /Users/poojaanil/opt/anaconda3/pkgs/matplotlib-base-3.4.3-py39h0a11d32_0/lib/python3.9/site-packages/matplotlib/backends/web_backend/nbagg_uat.ipynb : ['reload', 'matplotlib', 'matplotlib', 'matplotlib', 'matplotlib', 'new_figure_manager', 'matplotlib', 'numpy', 'matplotlib', 'itertools', 'time', 'itertools']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/JupyterWidgets.ipynb : ['ipywidgets']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Other Comms.ipynb : ['Comm']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/ipywidgets2.ipynb : ['ipywidgets']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/SVG.ipynb : ['SVG']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/sleep.ipynb : ['sleep', 'randint']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Autokill.ipynb : ['os', 'signal']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/update-display-id.ipynb : ['display']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Inline Image.ipynb : ['Image']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/ipywidgets_keep.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Check History in Memory.ipynb : ['get_ipython']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Output.ipynb : ['ipywidgets', 'clear_output', 'ipywidgets', 'ipywidgets', 'ipywidgets', 'ipywidgets', 'ipywidgets']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Clear Output.ipynb : ['print_function', 'clear_output']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/ipywidgets.nbconvert.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Parallel Execute A.ipynb : ['os', 'os', 'tempfile', 'time']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/ipywidgets_executed.ipynb : ['interact']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Parallel Execute B.ipynb : ['os', 'os', 'tempfile', 'time']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/ipywidgets.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/Sleep1s.ipynb : ['time', 'datetime']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/Autokill-checkpoint.ipynb : ['os', 'signal']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets2-checkpoint.ipynb : ['ipywidgets']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets.nbconvert-checkpoint.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets_executed-checkpoint.ipynb : ['interact']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets-checkpoint.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/sleep-checkpoint.ipynb : ['sleep', 'randint']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/Hang-checkpoint.ipynb : ['os', 'signal']
# /Users/poojaanil/opt/anaconda3/pkgs/nbclient-0.5.3-pyhd3eb1b0_0/site-packages/nbclient/tests/files/.ipynb_checkpoints/Sleep1s-checkpoint.ipynb : ['time', 'datetime']
# /Users/poojaanil/opt/anaconda3/pkgs/daal4py-2021.3.0-py39h01d92e1_0/info/test/examples/daal4py_data_science.ipynb : ['pandas', 'matplotlib', 'glob', 'sys', 'daal4py', 'pickle']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/info/test/nbconvert/tests/files/notebook1.ipynb : ['SymPy', 'init_printing']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/exporters/tests/files/notebook2.ipynb : ['NumPy', 'numpy']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/exporters/tests/files/svg.ipynb : ['matplotlib']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/exporters/tests/files/prompt_numbers.ipynb : ['numpy']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/exporters/tests/files/pngmetadata.ipynb : ['matplotlib']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/tests/files/notebook2.ipynb : ['NumPy', 'matplotlib', 'matplotlib', 'set_matplotlib_formats', 'numpy', 'math', 'numpy']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/tests/files/notebook4_jpeg.ipynb : ['Image']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/tests/files/notebook1.ipynb : ['SymPy', 'init_printing']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/tests/files/markdown_display_priority.ipynb : ['set_matplotlib_formats', 'matplotlib']
# /Users/poojaanil/opt/anaconda3/pkgs/nbconvert-6.1.0-py39hecd8cb5_0/lib/python3.9/site-packages/nbconvert/tests/files/Widget_List.ipynb : ['ipywidgets', 'datetime']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/JupyterWidgets.ipynb : ['ipywidgets']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Other Comms.ipynb : ['Comm']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/ipywidgets2.ipynb : ['ipywidgets']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/SVG.ipynb : ['SVG']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/sleep.ipynb : ['sleep', 'randint']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Autokill.ipynb : ['os', 'signal']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/update-display-id.ipynb : ['display']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Inline Image.ipynb : ['Image']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/ipywidgets_keep.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Check History in Memory.ipynb : ['get_ipython']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Output.ipynb : ['ipywidgets', 'clear_output', 'ipywidgets', 'ipywidgets', 'ipywidgets', 'ipywidgets', 'ipywidgets']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Clear Output.ipynb : ['print_function', 'clear_output']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/ipywidgets.nbconvert.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Parallel Execute A.ipynb : ['os', 'os', 'tempfile', 'time']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/ipywidgets_executed.ipynb : ['interact']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Parallel Execute B.ipynb : ['os', 'os', 'tempfile', 'time']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/ipywidgets.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/Sleep1s.ipynb : ['time', 'datetime']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/Autokill-checkpoint.ipynb : ['os', 'signal']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets2-checkpoint.ipynb : ['ipywidgets']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets.nbconvert-checkpoint.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets_executed-checkpoint.ipynb : ['interact']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/ipywidgets-checkpoint.ipynb : ['IntSlider']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/sleep-checkpoint.ipynb : ['sleep', 'randint']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/Hang-checkpoint.ipynb : ['os', 'signal']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbclient/tests/files/.ipynb_checkpoints/Sleep1s-checkpoint.ipynb : ['time', 'datetime']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/web_backend/nbagg_uat.ipynb : ['reload', 'matplotlib', 'matplotlib', 'matplotlib', 'matplotlib', 'new_figure_manager', 'matplotlib', 'numpy', 'matplotlib', 'itertools', 'time', 'itertools']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/exporters/tests/files/notebook2.ipynb : ['NumPy', 'numpy']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/exporters/tests/files/svg.ipynb : ['matplotlib']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/exporters/tests/files/prompt_numbers.ipynb : ['numpy']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/exporters/tests/files/pngmetadata.ipynb : ['matplotlib']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/tests/files/notebook2.ipynb : ['NumPy', 'matplotlib', 'matplotlib', 'set_matplotlib_formats', 'numpy', 'math', 'numpy']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/tests/files/notebook4_jpeg.ipynb : ['Image']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/tests/files/notebook1.ipynb : ['SymPy', 'init_printing']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/tests/files/markdown_display_priority.ipynb : ['set_matplotlib_formats', 'matplotlib']
# /Users/poojaanil/opt/anaconda3/lib/python3.9/site-packages/nbconvert/tests/files/Widget_List.ipynb : ['ipywidgets', 'datetime']
# /Users/poojaanil/.ipynb_checkpoints/lab04-checkpoint.ipynb : ['pandas']
# /Users/poojaanil/.ipynb_checkpoints/Homework2-checkpoint.ipynb : ['random', 'matplotlib', 'numpy', 'mean']
# /Users/poojaanil/.ipynb_checkpoints/hw-06-checkpoint.ipynb : ['ZipFile', 'request', 'pyplot', 'numpy']
# /Users/poojaanil/.ipynb_checkpoints/hw-08-checkpoint.ipynb : ['pandas', 'pandas', 're']
# /Users/poojaanil/.ipynb_checkpoints/midterm-checkpoint.ipynb : ['pandas', 'numpy', 'seaborn', 'pyplot', 'missingno']
# /Users/poojaanil/.ipynb_checkpoints/HW-03-checkpoint.ipynb : ['random', 'operator', 'random', 'datetime', 'date', 're']
# /Users/poojaanil/.ipynb_checkpoints/hw-07-checkpoint.ipynb : ['Faker', 'pandas', 'numpy', 'randint', 'random', 'seaborn', 'pyplot']
# /Users/poojaanil/.ipynb_checkpoints/week08_lab-checkpoint.ipynb : ['pandas', 'pandas', 'data', 're']
# /Users/poojaanil/.ipynb_checkpoints/hw-10-checkpoint.ipynb : ['os', 'pkg_resources', 'sys', 'json', 're']
# /Users/poojaanil/.ipynb_checkpoints/week10_lab-checkpoint.ipynb : ['numpy']
# /Users/poojaanil/.ipynb_checkpoints/lab3-checkpoint.ipynb : ['pandas']
# /Users/poojaanil/.ipynb_checkpoints/hw-04-checkpoint.ipynb : ['pandas', 'DataFrame', 'csv', 'math', 'seaborn', 'numpy', 'matplotlib']
# /Users/poojaanil/.ipynb_checkpoints/Get Browser History-checkpoint.ipynb : ['Firefox', 'browserhistory', 'pandas', 'urlparse']
# /Users/poojaanil/.ipynb_checkpoints/hw_09-checkpoint.ipynb : ['pandas', 'matplotlib', 'matplotlib']
# /Users/poojaanil/.ipynb_checkpoints/MIDTERM_DATA601-checkpoint.ipynb : ['pandas', 'pandas', 'numpy', 'random', 'seaborn', 'pyplot']
# /Users/poojaanil/.ipynb_checkpoints/hw10-browser_history-checkpoint.ipynb : ['pandas', 'matplotlib', 'matplotlib']
# /Users/poojaanil/.ipynb_checkpoints/MIDTERM_DATA601-Copy1-checkpoint.ipynb : ['pandas', 'pandas', 'numpy', 'random', 'seaborn', 'pyplot']
# /Users/poojaanil/.ipynb_checkpoints/week06_lab-checkpoint.ipynb : ['ZipFile', 'request', 'pandas', 'seaborn']
# /Users/poojaanil/.ipynb_checkpoints/week5_lab-checkpoint.ipynb : ['seaborn', 'pandas']
# /Users/poojaanil/.ipynb_checkpoints/lab2-checkpoint.ipynb : ['pandas', 'matplotlib']
# /Users/poojaanil/.ipynb_checkpoints/hw-05-checkpoint.ipynb : ['pandas', 'seaborn', 'pyplot', 'numpy']
# /Users/poojaanil/Downloads/hw-05.ipynb : ['pandas']
# /Users/poojaanil/Downloads/midterm.ipynb : ['pandas', 'numpy', 'seaborn', 'pyplot', 'missingno']
# /Users/poojaanil/Downloads/midterm (1).ipynb : ['pandas', 'numpy', 'seaborn', 'pyplot', 'missingno']
# /Users/poojaanil/Downloads/lab3.ipynb : ['pandas']
# /Users/poojaanil/Downloads/midterm (2).ipynb : ['pandas', 'numpy', 'seaborn', 'pyplot', 'missingno']
# /Users/poojaanil/Downloads/Copy_of_week08_lab.ipynb : ['pandas', 'pandas', 'ai', 'data', 'data', 'ai', 'data', 're']
# /Users/poojaanil/Downloads/week5_lab.ipynb : ['seaborn', 'pandas']
